# %% [markdown]
# Input Player Names

# %%
def player_name():
    player1 = input("Write your Playername here: ")
    player2 = input("Write your Playername here: ")
    print("Player 1 is: " + player1)
    print("Player 2 is: " + player2)
    return player1, player2

p1, p2 = player_name()

# %% [markdown]
# Choose randomly the first player

# %%
import random

def choose_first_player(p1, p2):
    first = random.choice([p1, p2])
    print(f" {first} starts!")
    return first

first_player = choose_first_player(p1, p2)

# %% [markdown]
# Create Matrix

# %%
def matrix():
    board = []
    for i in range(3):
        board.append({"A": i, "B": i, "C": i})
    return board

# %% [markdown]
# PRINT Matrix

# %%
def print_matrix(board):
    for row in board:
        print(row)

print_matrix(board)
# Out:
# {'A': 0, 'B': 0, 'C': 0}
# {'A': 1, 'B': 1, 'C': 1}
# {'A': 2, 'B': 2, 'C': 2}

# %% [markdown]
# Giving an Input from Player to the Board
